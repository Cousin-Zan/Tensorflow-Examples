# %%
import tensorflow as tf
import matplotlib.pyplot as plt
import glob
import os

# %%
TRAIN_IMG_DIR = '../input/cat-and-dog/training_set/training_set/*/*.jpg'
TEST_IMG_DIR = '../input/cat-and-dog/test_set/test_set/*/*.jpg'

# %%
train_img_path = glob.glob(TRAIN_IMG_DIR)
test_img_path = glob.glob(TEST_IMG_DIR)

# %%
import random
random.shuffle(train_img_path)
random.shuffle(test_img_path)

# %%
len(train_img_path)
# Out:
# 8005

# %%
train_img_path[:2]
# Out:
# ['../input/cat-and-dog/training_set/training_set/cats/cat.1726.jpg',
#  '../input/cat-and-dog/training_set/training_set/cats/cat.3756.jpg']

# %%
train_img_lab = [int(path.split('/')[5]=='cats') for path in train_img_path]
test_img_lab = [int(path.split('/')[5]=='cats') for path in test_img_path]

# %%
train_img_lab[-5:]
# Out:
# [0, 1, 1, 0, 1]

# %%
def getImgByPath_test(path,lab):
    img = tf.io.read_file(path)
    img = tf.image.decode_jpeg(img,channels=3)
    img = tf.image.resize(img,[256,256])
    img = tf.cast(img,tf.float32)
    img = img/255
#    lab = tf.reshape(lab,[1])
    return img,lab

# %%
def getImgByPath(path,lab):
    img = tf.io.read_file(path)
    img = tf.image.decode_jpeg(img,channels=3)
    img = tf.image.resize(img,[280,280])
    img = tf.image.random_crop(img,[256,256,3])
#    img = tf.image.random_flip_left_right(img)
#    img = tf.image.random_flip_up_down(img)
    img = tf.cast(img,tf.float32)
    img = img/255
#    lab = tf.reshape(lab,[1])
    return img,lab

# %%
train_img_ds = tf.data.Dataset.from_tensor_slices((train_img_path,train_img_lab))
test_img_ds = tf.data.Dataset.from_tensor_slices((test_img_path,test_img_lab))

# %%
AUTOTUNE = tf.data.experimental.AUTOTUNE

# %%
train_img_ds = train_img_ds.map(getImgByPath,num_parallel_calls=AUTOTUNE)
test_img_ds = test_img_ds.map(getImgByPath_test,num_parallel_calls=AUTOTUNE)

# %%
train_img_ds
# Out:
# <ParallelMapDataset shapes: ((256, 256, 3), ()), types: (tf.float32, tf.int32)>

# %%
test_img_ds
# Out:
# <ParallelMapDataset shapes: ((256, 256, 3), ()), types: (tf.float32, tf.int32)>

# %%
BATCH = 64
TRAIN_LEN  = len(train_img_path)
train_img_ds = train_img_ds.shuffle(300).batch(BATCH)
test_img_ds = test_img_ds.batch(BATCH)

# %%
train_img_ds = train_img_ds.prefetch(AUTOTUNE)
test_img_ds = test_img_ds.prefetch(AUTOTUNE)

# %%
model = tf.keras.Sequential()
model.add(tf.keras.layers.Conv2D(64,(3,3),input_shape=(256,256,3),activation='relu'))
model.add(tf.keras.layers.BatchNormalization())
model.add(tf.keras.layers.Conv2D(64,(3,3),activation='relu'))
model.add(tf.keras.layers.BatchNormalization())
model.add(tf.keras.layers.MaxPooling2D())
model.add(tf.keras.layers.Conv2D(128,(3,3),activation='relu'))
model.add(tf.keras.layers.BatchNormalization())
model.add(tf.keras.layers.Conv2D(128,(3,3),activation='relu'))
model.add(tf.keras.layers.BatchNormalization())
model.add(tf.keras.layers.MaxPooling2D())
model.add(tf.keras.layers.Conv2D(256,(3,3),activation='relu'))
model.add(tf.keras.layers.BatchNormalization())
model.add(tf.keras.layers.Conv2D(256,(3,3),activation='relu'))
model.add(tf.keras.layers.BatchNormalization())
model.add(tf.keras.layers.Conv2D(256,(1,1),activation='relu'))
model.add(tf.keras.layers.BatchNormalization())
model.add(tf.keras.layers.MaxPooling2D())
model.add(tf.keras.layers.Conv2D(512,(3,3),activation='relu'))
model.add(tf.keras.layers.BatchNormalization())
model.add(tf.keras.layers.Conv2D(512,(3,3),activation='relu'))
model.add(tf.keras.layers.BatchNormalization())
model.add(tf.keras.layers.Conv2D(512,(1,1),activation='relu'))
model.add(tf.keras.layers.BatchNormalization())
model.add(tf.keras.layers.MaxPooling2D())
model.add(tf.keras.layers.Conv2D(512,(3,3),activation='relu'))
model.add(tf.keras.layers.BatchNormalization())
model.add(tf.keras.layers.Conv2D(512,(3,3),activation='relu'))
model.add(tf.keras.layers.BatchNormalization())
model.add(tf.keras.layers.Conv2D(512,(1,1),activation='relu'))
model.add(tf.keras.layers.BatchNormalization())
model.add(tf.keras.layers.GlobalAveragePooling2D())
model.add(tf.keras.layers.Dense(4096,activation='relu'))
model.add(tf.keras.layers.BatchNormalization())
model.add(tf.keras.layers.Dense(4096,activation='relu'))
model.add(tf.keras.layers.BatchNormalization())
model.add(tf.keras.layers.Dense(1000,activation='relu'))
model.add(tf.keras.layers.BatchNormalization())
model.add(tf.keras.layers.Dense(1,activation='sigmoid'))

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 254, 254, 64)      1792
# _________________________________________________________________
# batch_normalization (BatchNo (None, 254, 254, 64)      256
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 252, 252, 64)      36928
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 252, 252, 64)      256
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 126, 126, 64)      0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 124, 124, 128)     73856
# _________________________________________________________________
# batch_normalization_2 (Batch (None, 124, 124, 128)     512
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 122, 122, 128)     147584
# _________________________________________________________________
# batch_normalization_3 (Batch (None, 122, 122, 128)     512
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 61, 61, 128)       0
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 59, 59, 256)       295168
# _________________________________________________________________
# batch_normalization_4 (Batch (None, 59, 59, 256)       1024
# _________________________________________________________________
# conv2d_5 (Conv2D)            (None, 57, 57, 256)       590080
# _________________________________________________________________
# batch_normalization_5 (Batch (None, 57, 57, 256)       1024
# _________________________________________________________________
# conv2d_6 (Conv2D)            (None, 57, 57, 256)       65792
# _________________________________________________________________
# batch_normalization_6 (Batch (None, 57, 57, 256)       1024
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 28, 28, 256)       0
# _________________________________________________________________
# conv2d_7 (Conv2D)            (None, 26, 26, 512)       1180160
# _________________________________________________________________
# batch_normalization_7 (Batch (None, 26, 26, 512)       2048
# _________________________________________________________________
# conv2d_8 (Conv2D)            (None, 24, 24, 512)       2359808
# _________________________________________________________________
# batch_normalization_8 (Batch (None, 24, 24, 512)       2048
# _________________________________________________________________
# conv2d_9 (Conv2D)            (None, 24, 24, 512)       262656
# _________________________________________________________________
# batch_normalization_9 (Batch (None, 24, 24, 512)       2048
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 12, 12, 512)       0
# _________________________________________________________________
# conv2d_10 (Conv2D)           (None, 10, 10, 512)       2359808
# _________________________________________________________________
# batch_normalization_10 (Batc (None, 10, 10, 512)       2048
# _________________________________________________________________
# conv2d_11 (Conv2D)           (None, 8, 8, 512)         2359808
# _________________________________________________________________
# batch_normalization_11 (Batc (None, 8, 8, 512)         2048
# _________________________________________________________________
# conv2d_12 (Conv2D)           (None, 8, 8, 512)         262656
# _________________________________________________________________
# batch_normalization_12 (Batc (None, 8, 8, 512)         2048
# _________________________________________________________________
# global_average_pooling2d (Gl (None, 512)               0
# _________________________________________________________________
# dense (Dense)                (None, 4096)              2101248
# _________________________________________________________________
# batch_normalization_13 (Batc (None, 4096)              16384
# _________________________________________________________________
# dense_1 (Dense)              (None, 4096)              16781312
# _________________________________________________________________
# batch_normalization_14 (Batc (None, 4096)              16384
# _________________________________________________________________
# dense_2 (Dense)              (None, 1000)              4097000
# _________________________________________________________________
# batch_normalization_15 (Batc (None, 1000)              4000
# _________________________________________________________________
# dense_3 (Dense)              (None, 1)                 1001
# =================================================================
# Total params: 33,030,321
# Trainable params: 33,003,489
# Non-trainable params: 26,832
# _________________________________________________________________

# %%
loss = tf.keras.losses.BinaryCrossentropy()
optimizer = tf.keras.optimizers.Adam(0.000001)

# %%
train_loss_avg = tf.keras.metrics.Mean('loss')
train_acc = tf.keras.metrics.Accuracy()
test_loss_avg = tf.keras.metrics.Mean('test_loss')
test_acc = tf.keras.metrics.Accuracy()

# %%
def train_setp(model,imgs,labs):
    with tf.GradientTape() as t:
        prognosis = model(imgs)
        loss_setp = loss(labs,prognosis)
    grads = t.gradient(loss_setp,model.trainable_variables)
    optimizer.apply_gradients(zip(grads,model.trainable_variables))
    train_loss_avg(loss_setp)
    train_acc(labs,tf.cast(prognosis>0.5,tf.int32))

# %%
def test_setp(model,imgs,labs):
    prognosis = model.predict(imgs)
    loss_setp = loss(labs,prognosis)
    test_loss_avg(loss_setp)
    test_acc(labs, tf.cast(prognosis>0.5, tf.int32))

# %%
train_loss_res = []
train_acc_res = []
test_loss_res = []
test_acc_res = []

# %%
train_epochs = 150

# %%
for epoch in range(train_epochs):
    print('epoch:{}\n'.format(epoch+1))
    for imgs,labs in train_img_ds:
        train_setp(model,imgs,labs)
        print('.',end='')
    train_loss_res.append(train_loss_avg.result())
    train_acc_res.append(train_acc.result())
    print('\ntrain_loss:{:.4f},train_acc:{:.4f}'.format(train_loss_avg.result(),train_acc.result()))
    train_loss_avg.reset_states()
    train_acc.reset_states()
    for imgs,labs in test_img_ds:
        test_setp(model,imgs,labs)
        print('.',end='')
    test_loss_res.append(test_loss_avg.result())
    test_acc_res.append(test_acc.result())
    print('\ntest_loss:{:.4f},test_acc:{:.4f}'.format(test_loss_avg.result(),test_acc.result()))
    test_loss_avg.reset_states()
    test_acc.reset_states()
# Out:
# epoch:1
#
# ..............................................................................................................................
# train_loss:0.6931,train_acc:0.5019
# ................................
# test_loss:0.6931,test_acc:0.5002
# epoch:2
#
# ..............................................................................................................................
# train_loss:0.6931,train_acc:0.5199
# ................................
# test_loss:0.6931,test_acc:0.5907
# epoch:3
#
# ..............................................................................................................................
# train_loss:0.6929,train_acc:0.5253
# ................................
# test_loss:0.6931,test_acc:0.5853
# epoch:4
#
# ..............................................................................................................................
# train_loss:0.6924,train_acc:0.5700
# ................................
# test_loss:0.6931,test_acc:0.6011
# epoch:5
#
# ..............................................................................................................................
# train_loss:0.6911,train_acc:0.5934
# ................................
# test_loss:0.6932,test_acc:0.5868
# epoch:6
#
# ..............................................................................................................................
# train_loss:0.6880,train_acc:0.5894
# ................................
# test_loss:0.6937,test_acc:0.5907
# epoch:7
#
# ..............................................................................................................................
# train_loss:0.6804,train_acc:0.6030
# ................................
# test_loss:0.6962,test_acc:0.6090
# epoch:8
#
# ..............................................................................................................................
# train_loss:0.6692,train_acc:0.6099
# ................................
# test_loss:0.7028,test_acc:0.6100
# epoch:9
#
# ..............................................................................................................................
# train_loss:0.6607,train_acc:0.6135
# ................................
# test_loss:0.7141,test_acc:0.5966
# epoch:10
#
# ..............................................................................................................................
# train_loss:0.6543,train_acc:0.6169
# ................................
# test_loss:0.7177,test_acc:0.6164
# epoch:11
#
# ..............................................................................................................................
# train_loss:0.6521,train_acc:0.6201
# ................................
# test_loss:0.7229,test_acc:0.6070
# epoch:12
#
# ..............................................................................................................................
# train_loss:0.6480,train_acc:0.6249
# ................................
# test_loss:0.7256,test_acc:0.6238
# epoch:13
#
# ..............................................................................................................................
# train_loss:0.6426,train_acc:0.6339
# ................................
# test_loss:0.7305,test_acc:0.6253
# epoch:14
#
# ..............................................................................................................................
# train_loss:0.6410,train_acc:0.6381
# ................................
# test_loss:0.7336,test_acc:0.6223
# epoch:15
#
# ..............................................................................................................................
# train_loss:0.6359,train_acc:0.6382
# ................................
# test_loss:0.7367,test_acc:0.6204
# epoch:16
#
# ..............................................................................................................................
# train_loss:0.6372,train_acc:0.6390
# ................................
# test_loss:0.7404,test_acc:0.6184
# epoch:17
#
# ..............................................................................................................................
# train_loss:0.6363,train_acc:0.6341
# ................................
# test_loss:0.7410,test_acc:0.6258
# epoch:18
#
# ..............................................................................................................................
# train_loss:0.6318,train_acc:0.6415
# ................................
# test_loss:0.7454,test_acc:0.6307
# epoch:19
#
# ..............................................................................................................................
# train_loss:0.6300,train_acc:0.6473
# ................................
# test_loss:0.7466,test_acc:0.6312
# epoch:20
#
# ..............................................................................................................................
# train_loss:0.6308,train_acc:0.6482
# ................................
# test_loss:0.7499,test_acc:0.6278
# epoch:21
#
# ..............................................................................................................................
# train_loss:0.6257,train_acc:0.6533
# ................................
# test_loss:0.7568,test_acc:0.6312
# epoch:22
#
# ..............................................................................................................................
# train_loss:0.6259,train_acc:0.6550
# ................................
# test_loss:0.7519,test_acc:0.6372
# epoch:23
#
# ..............................................................................................................................
# train_loss:0.6233,train_acc:0.6530
# ................................
# test_loss:0.7638,test_acc:0.6268
# epoch:24
#
# ..............................................................................................................................
# train_loss:0.6213,train_acc:0.6600
# ................................
# test_loss:0.7554,test_acc:0.6436
# epoch:25
#
# ..............................................................................................................................
# train_loss:0.6214,train_acc:0.6626
# ................................
# test_loss:0.7552,test_acc:0.6500
# epoch:26
#
# ..............................................................................................................................
# train_loss:0.6168,train_acc:0.6648
# ................................
# test_loss:0.7628,test_acc:0.6441
# epoch:27
#
# ..............................................................................................................................
# train_loss:0.6144,train_acc:0.6655
# ................................
# test_loss:0.7653,test_acc:0.6495
# epoch:28
#
# ..............................................................................................................................
# train_loss:0.6123,train_acc:0.6686
# ................................
# test_loss:0.7606,test_acc:0.6624
# epoch:29
#
# ..............................................................................................................................
# train_loss:0.6080,train_acc:0.6773
# ................................
# test_loss:0.7649,test_acc:0.6540
# epoch:30
#
# ..............................................................................................................................
# train_loss:0.6055,train_acc:0.6773
# ................................
# test_loss:0.7679,test_acc:0.6629
# epoch:31
#
# ..............................................................................................................................
# train_loss:0.6059,train_acc:0.6771
# ................................
# test_loss:0.7802,test_acc:0.6446
# epoch:32
#
# ..............................................................................................................................
# train_loss:0.6030,train_acc:0.6788
# ................................
# test_loss:0.7686,test_acc:0.6703
# epoch:33
#
# ..............................................................................................................................
# train_loss:0.5983,train_acc:0.6847
# ................................
# test_loss:0.7722,test_acc:0.6688
# epoch:34
#
# ..............................................................................................................................
# train_loss:0.5916,train_acc:0.6902
# ................................
# test_loss:0.7763,test_acc:0.6718
# epoch:35
#
# ..............................................................................................................................
# train_loss:0.5939,train_acc:0.6927
# ................................
# test_loss:0.7958,test_acc:0.6500
# epoch:36
#
# ..............................................................................................................................
# train_loss:0.5980,train_acc:0.6847
# ................................
# test_loss:0.7831,test_acc:0.6738
# epoch:37
#
# ..............................................................................................................................
# train_loss:0.5883,train_acc:0.6897
# ................................
# test_loss:0.7869,test_acc:0.6703
# epoch:38
#
# ..............................................................................................................................
# train_loss:0.5890,train_acc:0.6893
# ................................
# test_loss:0.7914,test_acc:0.6738
# epoch:39
#
# ..............................................................................................................................
# train_loss:0.5829,train_acc:0.6958
# ................................
# test_loss:0.7908,test_acc:0.6777
# epoch:40
#
# ..............................................................................................................................
# train_loss:0.5816,train_acc:0.6982
# ................................
# test_loss:0.7930,test_acc:0.6851
# epoch:41
#
# ..............................................................................................................................
# train_loss:0.5777,train_acc:0.7009
# ................................
# test_loss:0.7957,test_acc:0.6911
# epoch:42
#
# ..............................................................................................................................
# train_loss:0.5791,train_acc:0.7031
# ................................
# test_loss:0.8102,test_acc:0.6831
# epoch:43
#
# ..............................................................................................................................
# train_loss:0.5784,train_acc:0.7011
# ................................
# test_loss:0.8084,test_acc:0.6851
# epoch:44
#
# ..............................................................................................................................
# train_loss:0.5805,train_acc:0.7028
# ................................
# test_loss:0.8001,test_acc:0.6980
# epoch:45
#
# ..............................................................................................................................
# train_loss:0.5725,train_acc:0.7077
# ................................
# test_loss:0.8136,test_acc:0.6866
# epoch:46
#
# ..............................................................................................................................
# train_loss:0.5808,train_acc:0.7019
# ................................
# test_loss:0.8053,test_acc:0.6930
# epoch:47
#
# ..............................................................................................................................
# train_loss:0.5706,train_acc:0.7077
# ................................
# test_loss:0.8155,test_acc:0.6881
# epoch:48
#
# ..............................................................................................................................
# train_loss:0.5689,train_acc:0.7093
# ................................
# test_loss:0.8575,test_acc:0.6565
# epoch:49
#
# ..............................................................................................................................
# train_loss:0.5698,train_acc:0.7088
# ................................
# test_loss:0.8145,test_acc:0.6950
# epoch:50
#
# ..............................................................................................................................
# train_loss:0.5671,train_acc:0.7099
# ................................
# test_loss:0.8313,test_acc:0.6738
# epoch:51
#
# ..............................................................................................................................
# train_loss:0.5689,train_acc:0.7099
# ................................
# test_loss:0.8500,test_acc:0.6644
# epoch:52
#
# ..............................................................................................................................
# train_loss:0.5664,train_acc:0.7116
# ................................
# test_loss:0.8245,test_acc:0.6915
# epoch:53
#
# ..............................................................................................................................
# train_loss:0.5581,train_acc:0.7174
# ................................
# test_loss:0.8327,test_acc:0.6901
# epoch:54
#
# ..............................................................................................................................
# train_loss:0.5551,train_acc:0.7188
# ................................
# test_loss:0.8270,test_acc:0.7014
# epoch:55
#
# ..............................................................................................................................
# train_loss:0.5598,train_acc:0.7205
# ................................
# test_loss:0.8340,test_acc:0.6995
# epoch:56
#
# ..............................................................................................................................
# train_loss:0.5551,train_acc:0.7207
# ................................
# test_loss:0.8290,test_acc:0.7118
# epoch:57
#
# ..............................................................................................................................
# train_loss:0.5601,train_acc:0.7123
# ................................
# test_loss:0.8279,test_acc:0.7177
# epoch:58
#
# ..............................................................................................................................
# train_loss:0.5504,train_acc:0.7198
# ................................
# test_loss:0.8355,test_acc:0.7098
# epoch:59
#
# ..............................................................................................................................
# train_loss:0.5525,train_acc:0.7186
# ................................
# test_loss:0.8456,test_acc:0.7004
# epoch:60
#
# ..............................................................................................................................
# train_loss:0.5467,train_acc:0.7219
# ................................
# test_loss:0.8356,test_acc:0.7202
# epoch:61
#
# ..............................................................................................................................
# train_loss:0.5517,train_acc:0.7235
# ................................
# test_loss:0.8448,test_acc:0.7103
# epoch:62
#
# ..............................................................................................................................
# train_loss:0.5448,train_acc:0.7278
# ................................
# test_loss:0.8411,test_acc:0.7158
# epoch:63
#
# ..............................................................................................................................
# train_loss:0.5427,train_acc:0.7314
# ................................
# test_loss:0.8546,test_acc:0.7044
# epoch:64
#
# ..............................................................................................................................
# train_loss:0.5432,train_acc:0.7277
# ................................
# test_loss:0.8474,test_acc:0.7182
# epoch:65
#
# ..............................................................................................................................
# train_loss:0.5413,train_acc:0.7292
# ................................
# test_loss:0.8503,test_acc:0.7257
# epoch:66
#
# ..............................................................................................................................
# train_loss:0.5427,train_acc:0.7318
# ................................
# test_loss:0.8552,test_acc:0.7257
# epoch:67
#
# ..............................................................................................................................
# train_loss:0.5335,train_acc:0.7355
# ................................
# test_loss:0.8563,test_acc:0.7266
# epoch:68
#
# ..............................................................................................................................
# train_loss:0.5415,train_acc:0.7304
# ................................
# test_loss:0.8557,test_acc:0.7261
# epoch:69
#
# ..............................................................................................................................
# train_loss:0.5305,train_acc:0.7343
# ................................
# test_loss:0.8662,test_acc:0.7173
# epoch:70
#
# ..............................................................................................................................
# train_loss:0.5307,train_acc:0.7423
# ................................
# test_loss:0.8732,test_acc:0.7153
# epoch:71
#
# ..............................................................................................................................
# train_loss:0.5419,train_acc:0.7315
# ................................
# test_loss:0.8635,test_acc:0.7326
# epoch:72
#
# ..............................................................................................................................
# train_loss:0.5290,train_acc:0.7422
# ................................
# test_loss:0.8762,test_acc:0.7212
# epoch:73
#
# ..............................................................................................................................
# train_loss:0.5238,train_acc:0.7449
# ................................
# test_loss:0.8773,test_acc:0.7217
# epoch:74
#
# ..............................................................................................................................
# train_loss:0.5274,train_acc:0.7455
# ................................
# test_loss:0.8722,test_acc:0.7331
# epoch:75
#
# ..............................................................................................................................
# train_loss:0.5192,train_acc:0.7478
# ................................
# test_loss:0.9232,test_acc:0.6945
# epoch:76
#
# ..............................................................................................................................
# train_loss:0.5337,train_acc:0.7343
# ................................
# test_loss:0.8701,test_acc:0.7346
# epoch:77
#
# ..............................................................................................................................
# train_loss:0.5211,train_acc:0.7459
# ................................
# test_loss:0.8766,test_acc:0.7405
# epoch:78
#
# ..............................................................................................................................
# train_loss:0.5250,train_acc:0.7434
# ................................
# test_loss:0.8805,test_acc:0.7400
# epoch:79
#
# ..............................................................................................................................
# train_loss:0.5146,train_acc:0.7497
# ................................
# test_loss:0.9035,test_acc:0.7098
# epoch:80
#
# ..............................................................................................................................
# train_loss:0.5209,train_acc:0.7447
# ................................
# test_loss:0.8900,test_acc:0.7410
# epoch:81
#
# ..............................................................................................................................
# train_loss:0.5133,train_acc:0.7500
# ................................
# test_loss:0.8924,test_acc:0.7439
# epoch:82
#
# ..............................................................................................................................
# train_loss:0.5092,train_acc:0.7590
# ................................
# test_loss:0.9107,test_acc:0.7276
# epoch:83
#
# ..............................................................................................................................
# train_loss:0.5128,train_acc:0.7567
# ................................
# test_loss:0.8994,test_acc:0.7464
# epoch:84
#
# ..............................................................................................................................
# train_loss:0.5044,train_acc:0.7562
# ................................
# test_loss:0.9151,test_acc:0.7360
# epoch:85
#
# ..............................................................................................................................
# train_loss:0.5094,train_acc:0.7502
# ................................
# test_loss:0.9044,test_acc:0.7454
# epoch:86
#
# ..............................................................................................................................
# train_loss:0.5142,train_acc:0.7542
# ................................
# test_loss:0.9038,test_acc:0.7479
# epoch:87
#
# ..............................................................................................................................
# train_loss:0.5071,train_acc:0.7562
# ................................
# test_loss:0.9201,test_acc:0.7420
# epoch:88
#
# ..............................................................................................................................
# train_loss:0.5148,train_acc:0.7470
# ................................
# test_loss:0.9073,test_acc:0.7454
# epoch:89
#
# ..............................................................................................................................
# train_loss:0.5015,train_acc:0.7590
# ................................
# test_loss:0.9158,test_acc:0.7415
# epoch:90
#
# ..............................................................................................................................
# train_loss:0.5119,train_acc:0.7547
# ................................
# test_loss:0.9310,test_acc:0.7316
# epoch:91
#
# ..............................................................................................................................
# train_loss:0.5024,train_acc:0.7604
# ................................
# test_loss:0.9101,test_acc:0.7578
# epoch:92
#
# ..............................................................................................................................
# train_loss:0.5051,train_acc:0.7543
# ................................
# test_loss:0.9266,test_acc:0.7420
# epoch:93
#
# ..............................................................................................................................
# train_loss:0.4997,train_acc:0.7590
# ................................
# test_loss:0.9248,test_acc:0.7430
# epoch:94
#
# ..............................................................................................................................
# train_loss:0.4951,train_acc:0.7644
# ................................
# test_loss:0.9289,test_acc:0.7444
# epoch:95
#
# ..............................................................................................................................
# train_loss:0.4949,train_acc:0.7620
# ................................
# test_loss:0.9305,test_acc:0.7464
# epoch:96
#
# ..............................................................................................................................
# train_loss:0.4937,train_acc:0.7640
# ................................
# test_loss:0.9282,test_acc:0.7588
# epoch:97
#
# ..............................................................................................................................
# train_loss:0.4921,train_acc:0.7615
# ................................
# test_loss:0.9253,test_acc:0.7642
# epoch:98
#
# ..............................................................................................................................
# train_loss:0.4976,train_acc:0.7592
# ................................
# test_loss:0.9290,test_acc:0.7617
# epoch:99
#
# ..............................................................................................................................
# train_loss:0.4915,train_acc:0.7658
# ................................
# test_loss:0.9405,test_acc:0.7454
# epoch:100
#
# ..............................................................................................................................
# train_loss:0.4953,train_acc:0.7643
# ................................
# test_loss:0.9334,test_acc:0.7667
# epoch:101
#
# ..............................................................................................................................
# train_loss:0.4867,train_acc:0.7688
# ................................
# test_loss:0.9358,test_acc:0.7622
# epoch:102
#
# ..............................................................................................................................
# train_loss:0.4884,train_acc:0.7701
# ................................
# test_loss:0.9427,test_acc:0.7672
# epoch:103
#
# ..............................................................................................................................
# train_loss:0.4899,train_acc:0.7654
# ................................
# test_loss:0.9402,test_acc:0.7657
# epoch:104
#
# ..............................................................................................................................
# train_loss:0.4856,train_acc:0.7728
# ................................
# test_loss:0.9444,test_acc:0.7677
# epoch:105
#
# ..............................................................................................................................
# train_loss:0.4836,train_acc:0.7728
# ................................
# test_loss:0.9435,test_acc:0.7682
# epoch:106
#
# ..............................................................................................................................
# train_loss:0.4836,train_acc:0.7728
# ................................
# test_loss:0.9538,test_acc:0.7652
# epoch:107
#
# ..............................................................................................................................
# train_loss:0.4799,train_acc:0.7730
# ................................
# test_loss:0.9651,test_acc:0.7588
# epoch:108
#
# ..............................................................................................................................
# train_loss:0.4857,train_acc:0.7703
# ................................
# test_loss:0.9626,test_acc:0.7617
# epoch:109
#
# ..............................................................................................................................
# train_loss:0.4807,train_acc:0.7763
# ................................
# test_loss:0.9509,test_acc:0.7692
# epoch:110
#
# ..............................................................................................................................
# train_loss:0.4723,train_acc:0.7843
# ................................
# test_loss:1.0101,test_acc:0.7395
# epoch:111
#
# ..............................................................................................................................
# train_loss:0.4833,train_acc:0.7700
# ................................
# test_loss:0.9658,test_acc:0.7627
# epoch:112
#
# ..............................................................................................................................
# train_loss:0.4751,train_acc:0.7799
# ................................
# test_loss:0.9567,test_acc:0.7696
# epoch:113
#
# ..............................................................................................................................
# train_loss:0.4693,train_acc:0.7794
# ................................
# test_loss:0.9581,test_acc:0.7751
# epoch:114
#
# ..............................................................................................................................
# train_loss:0.4769,train_acc:0.7756
# ................................
# test_loss:0.9666,test_acc:0.7741
# epoch:115
#
# ..............................................................................................................................
# train_loss:0.4757,train_acc:0.7771
# ................................
# test_loss:0.9683,test_acc:0.7726
# epoch:116
#
# ..............................................................................................................................
# train_loss:0.4764,train_acc:0.7816
# ................................
# test_loss:0.9764,test_acc:0.7706
# epoch:117
#
# ..............................................................................................................................
# train_loss:0.4688,train_acc:0.7821
# ................................
# test_loss:0.9765,test_acc:0.7696
# epoch:118
#
# ..............................................................................................................................
# train_loss:0.4684,train_acc:0.7810
# ................................
# test_loss:0.9749,test_acc:0.7776
# epoch:119
#
# ..............................................................................................................................
# train_loss:0.4781,train_acc:0.7685
# ................................
# test_loss:1.0605,test_acc:0.7257
# epoch:120
#
# ..............................................................................................................................
# train_loss:0.4779,train_acc:0.7744
# ................................
# test_loss:0.9855,test_acc:0.7761
# epoch:121
#
# ..............................................................................................................................
# train_loss:0.4692,train_acc:0.7806
# ................................
# test_loss:0.9730,test_acc:0.7761
# epoch:122
#
# ..............................................................................................................................
# train_loss:0.4630,train_acc:0.7816
# ................................
# test_loss:0.9769,test_acc:0.7805
# epoch:123
#
# ..............................................................................................................................
# train_loss:0.4597,train_acc:0.7856
# ................................
# test_loss:0.9980,test_acc:0.7746
# epoch:124
#
# ..............................................................................................................................
# train_loss:0.4697,train_acc:0.7821
# ................................
# test_loss:1.0634,test_acc:0.7430
# epoch:125
#
# ..............................................................................................................................
# train_loss:0.4612,train_acc:0.7848
# ................................
# test_loss:1.0135,test_acc:0.7667
# epoch:126
#
# ..............................................................................................................................
# train_loss:0.4620,train_acc:0.7881
# ................................
# test_loss:0.9883,test_acc:0.7820
# epoch:127
#
# ..............................................................................................................................
# train_loss:0.4569,train_acc:0.7849
# ................................
# test_loss:0.9895,test_acc:0.7716
# epoch:128
#
# ..............................................................................................................................
# train_loss:0.4726,train_acc:0.7799
# ................................
# test_loss:0.9936,test_acc:0.7785
# epoch:129
#
# ..............................................................................................................................
# train_loss:0.4722,train_acc:0.7783
# ................................
# test_loss:1.0133,test_acc:0.7721
# epoch:130
#
# ..............................................................................................................................
# train_loss:0.4844,train_acc:0.7766
# ................................
# test_loss:0.9799,test_acc:0.7825
# epoch:131
#
# ..............................................................................................................................
# train_loss:0.4617,train_acc:0.7836
# ................................
# test_loss:0.9883,test_acc:0.7721
# epoch:132
#
# ..............................................................................................................................
# train_loss:0.4615,train_acc:0.7825
# ................................
# test_loss:0.9975,test_acc:0.7845
# epoch:133
#
# ..............................................................................................................................
# train_loss:0.4516,train_acc:0.7925
# ................................
# test_loss:1.0078,test_acc:0.7825
# epoch:134
#
# ..............................................................................................................................
# train_loss:0.4572,train_acc:0.7890
# ................................
# test_loss:1.0014,test_acc:0.7830
# epoch:135
#
# ..............................................................................................................................
# train_loss:0.4575,train_acc:0.7885
# ................................
# test_loss:1.0250,test_acc:0.7790
# epoch:136
#
# ..............................................................................................................................
# train_loss:0.4625,train_acc:0.7865
# ................................
# test_loss:1.0483,test_acc:0.7672
# epoch:137
#
# ..............................................................................................................................
# train_loss:0.4561,train_acc:0.7920
# ................................
# test_loss:1.0212,test_acc:0.7795
# epoch:138
#
# ..............................................................................................................................
# train_loss:0.4483,train_acc:0.7930
# ................................
# test_loss:1.0064,test_acc:0.7790
# epoch:139
#
# ..............................................................................................................................
# train_loss:0.4494,train_acc:0.7923
# ................................
# test_loss:1.0108,test_acc:0.7865
# epoch:140
#
# ..............................................................................................................................
# train_loss:0.4540,train_acc:0.7919
# ................................
# test_loss:1.0113,test_acc:0.7785
# epoch:141
#
# ..............................................................................................................................
# train_loss:0.4585,train_acc:0.7890
# ................................
# test_loss:1.0089,test_acc:0.7825
# epoch:142
#
# ..............................................................................................................................
# train_loss:0.4524,train_acc:0.7914
# ................................
# test_loss:1.0298,test_acc:0.7598
# epoch:143
#
# ..............................................................................................................................
# train_loss:0.4562,train_acc:0.7914
# ................................
# test_loss:1.0522,test_acc:0.7751
# epoch:144
#
# ..............................................................................................................................
# train_loss:0.4533,train_acc:0.7855
# ................................
# test_loss:1.0210,test_acc:0.7860
# epoch:145
#
# ..............................................................................................................................
# train_loss:0.4503,train_acc:0.7914
# ................................
# test_loss:1.0222,test_acc:0.7904
# epoch:146
#
# ..............................................................................................................................
# train_loss:0.4526,train_acc:0.7905
# ................................
# test_loss:1.0341,test_acc:0.7642
# epoch:147
#
# ..............................................................................................................................
# train_loss:0.4542,train_acc:0.7909
# ................................
# test_loss:1.0467,test_acc:0.7781
# epoch:148
#
# ..............................................................................................................................
# train_loss:0.4573,train_acc:0.7865
# ................................
# test_loss:1.0197,test_acc:0.7860
# epoch:149
#
# ..............................................................................................................................
# train_loss:0.4517,train_acc:0.7859
# ................................
# test_loss:1.0187,test_acc:0.7874
# epoch:150
#
# ..............................................................................................................................
# train_loss:0.4497,train_acc:0.7914
# ................................
# test_loss:1.0171,test_acc:0.7850
